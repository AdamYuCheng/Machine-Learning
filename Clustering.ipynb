# %% [markdown]
# # Basic KMean Clustering Method

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %pylab inline
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 30)
sns.set(style="white", color_codes=True)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# %%
x, y = make_blobs(n_samples=1000, random_state=1)

# %%
kmeans = KMeans(n_clusters=3)

# %%
pred = kmeans.fit(x).predict(x)

# %%
plt.scatter(x[:,0], x[:,1], c=pred)

# %% [markdown]
# # Visualize the clustering using the dendrogram

# %%
from scipy.cluster.hierarchy import dendrogram, ward

# %%
x1, y1 = make_blobs(n_samples=20, random_state=1)
link = ward(x1)
dendrogram(link)
# Out:
# {'color_list': ['g',
#   'g',
#   'g',
#   'g',
#   'g',
#   'g',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'b'],
#  'dcoord': [[0.0, 0.65544333023610424, 0.65544333023610424, 0.0],
#   [0.0, 1.0640222791973841, 1.0640222791973841, 0.65544333023610424],
#   [0.0, 0.64368023547867248, 0.64368023547867248, 0.0],
#   [0.0, 0.69862709594344119, 0.69862709594344119, 0.0],
#   [0.64368023547867248,
#    1.8106048531459471,
#    1.8106048531459471,
#    0.69862709594344119],
#   [1.0640222791973841,
#    3.2918292244823464,
#    3.2918292244823464,
#    1.8106048531459471],
#   [0.0, 0.076208250715041601, 0.076208250715041601, 0.0],
#   [0.0, 1.237821444400016, 1.237821444400016, 0.076208250715041601],
#   [0.0, 0.31450781827064073, 0.31450781827064073, 0.0],
#   [0.0, 1.173024452399317, 1.173024452399317, 0.31450781827064073],
#   [0.0, 1.7855741292336706, 1.7855741292336706, 1.173024452399317],
#   [1.237821444400016,
#    2.8763268160693451,
#    2.8763268160693451,
#    1.7855741292336706],
#   [0.0, 0.49715050864729127, 0.49715050864729127, 0.0],
#   [0.0, 0.3846310716906185, 0.3846310716906185, 0.0],
#   [0.0, 0.71442452286409397, 0.71442452286409397, 0.3846310716906185],
#   [0.49715050864729127,
#    1.3881924657693121,
#    1.3881924657693121,
#    0.71442452286409397],
#   [0.0, 3.3414273306900864, 3.3414273306900864, 1.3881924657693121],
#   [2.8763268160693451,
#    13.091580495310287,
#    13.091580495310287,
#    3.3414273306900864],
#   [3.2918292244823464,
#    36.405487112439864,
#    36.405487112439864,
#    13.091580495310287]],
#  'icoord': [[15.0, 15.0, 25.0, 25.0],
#   [5.0, 5.0, 20.0, 20.0],
#   [35.0, 35.0, 45.0, 45.0],
#   [55.0, 55.0, 65.0, 65.0],
#   [40.0, 40.0, 60.0, 60.0],
#   [12.5, 12.5, 50.0, 50.0],
#   [85.0, 85.0, 95.0, 95.0],
#   [75.0, 75.0, 90.0, 90.0],
#   [125.0, 125.0, 135.0, 135.0],
#   [115.0, 115.0, 130.0, 130.0],
#   [105.0, 105.0, 122.5, 122.5],
#   [82.5, 82.5, 113.75, 113.75],
#   [155.0, 155.0, 165.0, 165.0],
#   [185.0, 185.0, 195.0, 195.0],
#   [175.0, 175.0, 190.0, 190.0],
#   [160.0, 160.0, 182.5, 182.5],
#   [145.0, 145.0, 171.25, 171.25],
#   [98.125, 98.125, 158.125, 158.125],
#   [31.25, 31.25, 128.125, 128.125]],
#  'ivl': ['16',
#   '10',
#   '17',
#   '2',
#   '11',
#   '8',
#   '12',
#   '7',
#   '3',
#   '9',
#   '4',
#   '5',
#   '15',
#   '18',
#   '14',
#   '0',
#   '6',
#   '19',
#   '1',
#   '13'],
#  'leaves': [16,
#   10,
#   17,
#   2,
#   11,
#   8,
#   12,
#   7,
#   3,
#   9,
#   4,
#   5,
#   15,
#   18,
#   14,
#   0,
#   6,
#   19,
#   1,
#   13]}
